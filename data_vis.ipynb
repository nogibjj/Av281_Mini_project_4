# %%
import pandas as pd
import matplotlib.pyplot as plt


def PDdescribe(filename):
    """function which returns descriptive stats about input data"""
    df = pd.read_csv(filename)
    return df.describe()


results = PDdescribe("nba.csv")
print("Summary statistics for nba.csv:")
print(results)
print("")
print("Data Visualization for nba.csv:")
nba = pd.read_csv("nba.csv")
plt.figure(figsize=(10, 8))
plt.scatter(nba["Age"], nba["Weight"])
plt.title("NBA player Weight vs Age")
plt.xlabel("Height")
plt.ylabel("Age")
plt.show(block=True)
# Out:
# Summary statistics for nba.csv:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07
#
# Data Visualization for nba.csv:
